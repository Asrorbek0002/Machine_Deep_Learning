# %% [markdown]
# => library calling

# %%
# %pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastai.vision.all import *
from ipywidgets import widgets
from IPython.display import display
from io import BytesIO

# %% [markdown]
# => data which Oxford was downloaded

# %%
path = untar_data(URLs.PETS)/"images"
files = get_image_files(path)



# Label function

def is_cat(x):
     return x[0].isupper()


# datadownloaders

dls = ImageDataLoaders.from_name_func(
     path, files, valid = 0.2, seed = 42,
     label_func = is_cat, item_tfms = Resize(224)
)

# %% [markdown]
# => Model training

# %%
learn = cnn_learner(dls, resnet34, metrics = accuracy)
learn.fine_tune(2)
# Out:
# c:\Users\Asrorbek\AppData\Local\Programs\Python\Python310\lib\site-packages\fastai\vision\learner.py:303: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
# ...

# %% [markdown]
# => Download this model

# %%
# learn.export('d:/PycharmProjects/AllProjects_of_Python/DeepLearning/Model_CatImage/model.pkl')

# %% [markdown]
# => Upload this model

# %%
#learn = load_learner('d:/PycharmProjects/AllProjects_of_Python/DeepLearning/Model_CatImage/model.pkl')

# %% [markdown]
# => to check the working of model

# %% [markdown]
# to use widget for images downloading

# %%
upload = widgets.FileUpload()
display(upload)
# Out:
# FileUpload(value=(), description='Upload')

# %%
# to check File downloading
if upload.value:
    file_info = upload.value[0]  # Tuple 1-element (dictionary)
    img_data = file_info['content']  # photo binay informatiion

    # photo downloading
    img = PILImage.create(BytesIO(img_data))

    # to see photo
    img.show()

    # to see prediction via Model
    pred, _, prob = learn.predict(img)
    print(f"Model predict: {pred}")
    print(f"Accuracy prediction: {prob}")
else:
    print("Fayl hali yuklanmagan.")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Model predict: True
# Accuracy prediction: tensor([9.6157e-17, 1.0000e+00])

# %% [markdown]
# => to explore this model untar_dato function

# %%
path = untar_data(URLs.PETS)/'images'
path
# Out:
# Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images')

# %%
path.ls()
# Out:
# (#7393) [Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_1.jpg'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_10.jpg'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_100.jpg'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_100.mat'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_101.jpg'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_101.mat'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_102.jpg'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_102.mat'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_103.jpg'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_104.jpg'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_105.jpg'),Path('C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images/Abyssinian_106.jpg'),Path('C:/Users/Asror
# ...

# %%
# !dir "C:/Users/Asrorbek/.fastai/data/oxford-iiit-pet/images"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 84EC-7985
#
#  Directory of C:\Users\Asrorbek\.fastai\data\oxford-iiit-pet\images
#
# 06/18/2012  09:54 PM    <DIR>          .
# 10/09/2018  03:17 AM    <DIR>          ..
# 06/18/2012  09:54 PM            32,362 Abyssinian_1.jpg
# 06/18/2012  09:52 PM            96,294 Abyssinian_10.jpg
# 06/18/2012  09:52 PM           126,923 Abyssinian_100.jpg
# 06/18/2012  09:53 PM         1,351,002 Abyssinian_100.mat
# 06/18/2012  09:53 PM            49,023 Abyssinian_101.jpg
# 06/18/2012  09:52 PM           956,090 Abyssinian_101.mat
# 06/18/2012  09:53 PM           165,505 Abyssinian_102.jpg
# 06/18/2012  09:53 PM         1,611,487 Abyssinian_102.mat
# 06/18/2012  09:54 PM           132,937 Abyssinian_103.jpg
# 06/18/2012  09:54 PM            34,907 Abyssinian_104.jpg
# 06/18/2012  09:53 PM           141,823 Abyssinian_105.jpg
# 06/18/2012  09:52 PM           197,092 Abyssinian_106.jpg
# ...

# %%
print(len(files))
# Out:
# 7390

# %% [markdown]
# => cnn_learner() Convolutional Neural Networks (CNN) for Computer Vision

# %%
learn = cnn_learner(dls, resnet34, metrics = accuracy)
learn.fine_tune(2)
# Out:
# c:\Users\Asrorbek\AppData\Local\Programs\Python\Python310\lib\site-packages\fastai\vision\learner.py:303: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
# ...
